# %%
import pandas as pd
import gradio as gr
import numpy as np

# %%
#algorithm from google
def knapSack(W, wt, val, n):
  
    # Base Case
    if n == 0 or W == 0 :
        return 0
  
    # If weight of the nth item is more than Knapsack of capacity
    # W, then this item cannot be included in the optimal solution
    if (wt[n-1] > W):
        return knapSack(W, wt, val, n-1)
  
    # return the maximum of two cases:
    # (1) nth item included
    # (2) not included
    else:
        return max(val[n-1] + knapSack(W-wt[n-1], wt, val, n-1),
                   knapSack(W, wt, val, n-1))
  
# end of function knapSack
  
# To test above function

# %%
val = [600, 200, 3600]
wt = [10, 20, 30]
W = 50
n = len(val)
print(knapSack(W, wt, val,n))
# Out:
# 4200

# %%
#the solution
val = [600, 200, 3600]
wt = [10, 20, 30]
W = 50
kuri= ["Banne", "onion", "pomme"]
data={"object name":kuri,"weight":wt,"value":val}
df= pd.DataFrame(data)
df=df.sort_values(by=['value'], ascending=False)
df
# Out:
#   object name  weight  value
# 2       pomme      30   3600
# 0       Banne      10    600
# 1       onion      20    200

# %%
def tri(l,W):
    l.dropna
    l= l[l.weight <=W]
    l= l[l.weight >0]
    l=l[l.value >0]
    for i in range(0,len(l.index)):
        l["value"].loc[l.index[i]]=l["value"].loc[l.index[i]]/l["weight"].loc[l.index[i]]
    l=l.sort_values(by=['value'], ascending=False)
    k=0
    h=0
    o=""
    for i in range(0,len(l.index)):
        k=k+l["weight"].loc[l.index[i]]*(W//l["weight"].loc[l.index[i]])*l["value"].loc[l.index[i]]
        h=h+l["weight"].loc[l.index[i]]*(W//l["weight"].loc[l.index[i]])
        o=o+str(W//l["weight"].loc[l.index[i]])+l["object name"].loc[l.index[i]]+" "
        W=W-l["weight"].loc[l.index[i]]*(W//l["weight"].loc[l.index[i]])
    return h,k,o

# %%
tri(df,70)
# Out:
# C:\Users\TRETEC\AppData\Local\Temp\ipykernel_12020\3757603165.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   l["value"].loc[l.index[i]]=l["value"].loc[l.index[i]]/l["weight"].loc[l.index[i]]
# (70, 7800, '2pomme 1Banne 0onion ')

# %%
input=gr.Dataframe(
            headers=["object name", "weight", "value"],
            datatype=["str", "number", "number"],
            row_count=3,
            col_count=(3, "fixed"))
#outputs = [gr.Dataframe(row_count = (1, "dynamic"), col_count=(2, "fixed"), label="Predictions", headers=["best combination","best value"])]
demo=gr.Interface(fn=tri, inputs=[input,gr.Number(label="bag weight")],outputs=[gr.Number(label="maximum weight"),gr.Number(label="best value"),gr.Textbox(label="Best Combination")],title="Bin Packing",examples=[[df]])
demo.launch(debug=True,share=True)
# Out:
# Running on local URL:  http://127.0.0.1:7860
#
# Could not create share link. Please check your internet connection or our status page: https://status.gradio.app
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Traceback (most recent call last):
#   File "c:\Users\TRETEC\AppData\Local\Programs\Python\Python311\Lib\site-packages\gradio\routes.py", line 401, in run_predict
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\TRETEC\AppData\Local\Programs\Python\Python311\Lib\site-packages\gradio\blocks.py", line 1302, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\TRETEC\AppData\Local\Programs\Python\Python311\Lib\site-packages\gradio\blocks.py", line 1025, in call_function
#     prediction = await anyio.to_thread.run_sync(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\TRETEC\AppData\Local\Programs\Python\Python311\Lib\site-packages\anyio\to_thread.py", line 31, in run_sync
#     return await get_asynclib().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\TRETEC\AppData\Local\Programs\Python\Python311\Lib\site-packages\anyio\_backends\_asyncio.py", line 937, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "c:\Users\TRETEC\AppData\Local\Programs\Python\Python311\Lib\site-packages\anyio\_backends\_asyncio.py", line 867, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\TRETEC\AppData\Local\Temp\ipykernel_12020\3757603165.py", line 5, in tri
#     l=l[l.value >0]
#         ^^^^^^^^^^
#   File "c:\Users\TRETEC\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\ops\common.py", line 72, in new_method
#     return method(self, other)
#            ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\TRETEC\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\arraylike.py", line 58, in __gt__
#     return self._cmp_method(other, operator.gt)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\TRETEC\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py", line 6243, in _cmp_method
#     res_values = ops.comparison_op(lvalues, rvalues, op)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\TRETEC\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\ops\array_ops.py", line 287, in comparison_op
#     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\TRETEC\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\ops\array_ops.py", line 75, in comp_method_OBJECT_ARRAY
#     result = libops.scalar_compare(x.ravel(), y, op)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "pandas\_libs\ops.pyx", line 107, in pandas._libs.ops.scalar_compare
# TypeError: '>' not supported between instances of 'str' and 'int'
# C:\Users\TRETEC\AppData\Local\Temp\ipykernel_12020\3757603165.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   l["value"].loc[l.index[i]]=l["value"].loc[l.index[i]]/l["weight"].loc[l.index[i]]
# C:\Users\TRETEC\AppData\Local\Temp\ipykernel_12020\3757603165.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   l["value"].loc[l.index[i]]=l["value"].loc[l.index[i]]/l["weight"].loc[l.index[i]]
# Traceback (most recent call last):
#   File "c:\Users\TRETEC\AppData\Local\Programs\Python\Python311\Lib\site-packages\gradio\routes.py", line 401, in run_predict
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\TRETEC\AppData\Local\Programs\Python\Python311\Lib\site-packages\gradio\blocks.py", line 1302, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\TRETEC\AppData\Local\Programs\Python\Python311\Lib\site-packages\gradio\blocks.py", line 1025, in call_function
#     prediction = await anyio.to_thread.run_sync(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\TRETEC\AppData\Local\Programs\Python\Python311\Lib\site-packages\anyio\to_thread.py", line 31, in run_sync
#     return await get_asynclib().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\TRETEC\AppData\Local\Programs\Python\Python311\Lib\site-packages\anyio\_backends\_asyncio.py", line 937, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "c:\Users\TRETEC\AppData\Local\Programs\Python\Python311\Lib\site-packages\anyio\_backends\_asyncio.py", line 867, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\TRETEC\AppData\Local\Temp\ipykernel_12020\3757603165.py", line 3, in tri
#     l= l[l.weight <=W]
#          ^^^^^^^^^^^^
#   File "c:\Users\TRETEC\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\ops\common.py", line 72, in new_method
#     return method(self, other)
#            ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\TRETEC\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\arraylike.py", line 54, in __le__
#     return self._cmp_method(other, operator.le)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\TRETEC\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py", line 6243, in _cmp_method
#     res_values = ops.comparison_op(lvalues, rvalues, op)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\TRETEC\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\ops\array_ops.py", line 287, in comparison_op
#     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\TRETEC\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\ops\array_ops.py", line 75, in comp_method_OBJECT_ARRAY
#     result = libops.scalar_compare(x.ravel(), y, op)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "pandas\_libs\ops.pyx", line 107, in pandas._libs.ops.scalar_compare
# TypeError: '<=' not supported between instances of 'str' and 'float'
# Keyboard interruption in main thread... closing server.
